# %% [markdown]
# #Obtendo o HTML e criando o objeto BeautifulSoup

# %%
import bs4
import urllib.request as urllib_request
import pandas 

from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://alura-site-scraping.herokuapp.com/index.php' 

response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Alura Motors</title>
# <style>
# 		/*Regra para a animacao*/
# 		@keyframes spin {
# 			0% { transform: rotate(0deg); }
# 			100% { transform: rotate(360deg); }
# 		}
# 		/*Mudando o tamanho do icone de resposta*/
# 		div.glyphicon {
# 			color:#6B8E23;
# 			font-size: 38px;
# 		}
# 		/*Classe que mostra a animacao 'spin'*/
# 		.loader {
# 			border: 16px solid #f3f3f3;
# 			border-radius: 50%;
# 			border-top: 16px solid #3498db;
# 			width: 80px;
# 			height: 80px;
# 			-webkit-animation: spin 2s linear infinite;
# 			animation: spin 2s linear infinite;
# 		}
# 	</style>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# ...

# %% [markdown]
# #Criando variáveis para armazenar as informações

# %%
cards = []
card = {}

# %% [markdown]
# #Obtendo os dados do primeiro card

# %%
anuncio = soup.find('div', {'class': 'well card'})
anuncio
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>

# %% [markdown]
# #Obtendo o valor do veículo anunciado

# %%
anuncio.find('div', {'class': 'value-card'})
# Out:
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>

# %%
anuncio.find('p', {'class': 'txt-value'}).getText()
# Out:
# 'R$ 338.000'

# %%
card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()
card
# Out:
# {'value': 'R$ 338.000'}

# %%
# Resumo Valor
card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

# %% [markdown]
# #Obtendo as informações sobre o veículo anunciado

# %%
anuncio.find('div', {'class': 'body-card'}).findAll('p')
# Out:
# [<p class="txt-name inline">LAMBORGHINI AVENTADOR</p>,
#  <p class="txt-category badge badge-secondary inline">USADO</p>,
#  <p class="txt-motor">Motor 1.8 16v</p>,
#  <p class="txt-description">Ano 1993 - 55.286 km</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>]

# %%
infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')

# %%
for info in infos:
  print(info.get('class'), ' - ', info.getText())
# Out:
# ['txt-name', 'inline']  -  LAMBORGHINI AVENTADOR
# ['txt-category', 'badge', 'badge-secondary', 'inline']  -  USADO
# ['txt-motor']  -  Motor 1.8 16v
# ['txt-description']  -  Ano 1993 - 55.286 km
# ['txt-location']  -  Belo Horizonte - MG

# %%
for info in infos:
  print(info.get('class')[0], ' - ', info.getText())
# Out:
# txt-name  -  LAMBORGHINI AVENTADOR
# txt-category  -  USADO
# txt-motor  -  Motor 1.8 16v
# txt-description  -  Ano 1993 - 55.286 km
# txt-location  -  Belo Horizonte - MG

# %%
for info in infos:
  print(info.get('class')[0].split('-'), ' - ', info.getText())
# Out:
# ['txt', 'name']  -  LAMBORGHINI AVENTADOR
# ['txt', 'category']  -  USADO
# ['txt', 'motor']  -  Motor 1.8 16v
# ['txt', 'description']  -  Ano 1993 - 55.286 km
# ['txt', 'location']  -  Belo Horizonte - MG

# %%
for info in infos:
  print(info.get('class')[0].split('-')[-1], ' - ', info.getText())
# Out:
# name  -  LAMBORGHINI AVENTADOR
# category  -  USADO
# motor  -  Motor 1.8 16v
# description  -  Ano 1993 - 55.286 km
# location  -  Belo Horizonte - MG

# %%
for info in infos:
  card[info.get('class')[0].split('-')[-1]] = info.getText()

# %%
card
# Out:
# {'category': 'USADO',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG',
#  'motor': 'Motor 1.8 16v',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'value': 'R$ 338.000'}

# %%
# Resumo Infos

infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
for info in infos:
  card[info.get('class')[0].split('-')[-1]] = info.getText()

# %% [markdown]
# #Obtendo os acessórios do veículo anunciado

# %%
anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items.pop()
# Out:
# <li class="txt-items">...</li>

# %%
items
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>]

# %%
for item in items:
  print(item.getText().replace('► ', ''))
# Out:
# 4 X 4
# Câmera de estacionamento
# Controle de tração
# Sensor de estacionamento

# %%
acessorios = []
for item in items:
  acessorios.append(item.getText().replace('► ', ''))

acessorios
# Out:
# ['4 X 4',
#  'Câmera de estacionamento',
#  'Controle de tração',
#  'Sensor de estacionamento']

# %%
card['items'] = acessorios

# %%
card
# Out:
# {'category': 'USADO',
#  'description': 'Ano 1993 - 55.286 km',
#  'items': ['4 X 4',
#   'Câmera de estacionamento',
#   'Controle de tração',
#   'Sensor de estacionamento'],
#  'location': 'Belo Horizonte - MG',
#  'motor': 'Motor 1.8 16v',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'value': 'R$ 338.000'}

# %%
# Resumo Acessorios
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items.pop()
acessorios = []
for item in items:
  acessorios.append(item.getText().replace('► ', ''))
card['items'] = acessorios

# %% [markdown]
# # Criando um DataFrame com os dados coletados do Alura Motors

# %%
card
# Out:
# {'category': 'USADO',
#  'description': 'Ano 1993 - 55.286 km',
#  'items': ['4 X 4',
#   'Câmera de estacionamento',
#   'Controle de tração',
#   'Sensor de estacionamento'],
#  'location': 'Belo Horizonte - MG',
#  'motor': 'Motor 1.8 16v',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'value': 'R$ 338.000'}

# %%
import pandas as pd

# %%
dataset = pd.DataFrame(card)
dataset
# Out:
#         value  ...                     items
# 0  R$ 338.000  ...                     4 X 4
# 1  R$ 338.000  ...  Câmera de estacionamento
# 2  R$ 338.000  ...        Controle de tração
# 3  R$ 338.000  ...  Sensor de estacionamento
#
# [4 rows x 7 columns]

# %%
dataset = pd.DataFrame.from_dict(card, orient = 'index')
dataset
# Out:
#                                                              0
# value                                               R$ 338.000
# name                                     LAMBORGHINI AVENTADOR
# category                                                 USADO
# motor                                            Motor 1.8 16v
# description                               Ano 1993 - 55.286 km
# location                                   Belo Horizonte - MG
# items        [4 X 4, Câmera de estacionamento, Controle de ...

# %%
dataset = pd.DataFrame.from_dict(card, orient = 'index').T
dataset
# Out:
#         value  ...                                              items
# 0  R$ 338.000  ...  [4 X 4, Câmera de estacionamento, Controle de ...
#
# [1 rows x 7 columns]

# %%
dataset.to_csv('/content/drive/MyDrive/WEB SCRAPPING/output/data/dataset.csv', sep = ';', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # Obtendo a foto do anuncio

# %%
image = anuncio.find('div', {'class': 'image-card'}).img
image
# Out:
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>

# %%
print(image.get('src'))
# Out:
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg

# %%
# Visusalizando a Foto no notebook

from IPython.core.display import display, HTML

display(HTML(str(anuncio.find('div', {'class': 'image-card'}).img)))
# Out:
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>

# %%
display(HTML("<img src=" + anuncio.find('div', {'class' : 'image-card'}).img.get('src') + ">"))
# Out:
# <img src=https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg>

# %% [markdown]
# # Rotina para acessar e salvar a foto do anúncio

# %%
image.get('src').split('/')[-1]
# Out:
# 'lamborghini-aventador-2932196__340.jpg'

# %%
from urllib.request import urlretrieve

urlretrieve(image.get('src'), '/content/drive/MyDrive/WEB SCRAPPING/output/img' + image.get('src').split('/')[-1])
# Out:
# ('/content/drive/MyDrive/WEB SCRAPPING/output/imglamborghini-aventador-2932196__340.jpg',
#  <http.client.HTTPMessage at 0x7fb2b1e82e90>)

# %%
# Resumo Imagens

image = anuncio.find('div', {'class': 'image-card'}).img
urlretrieve(image.get('src'), '/content/drive/MyDrive/WEB SCRAPPING/output/img' + image.get('src').split('/')[-1])
# Out:
# ('/content/drive/MyDrive/WEB SCRAPPING/output/imglamborghini-aventador-2932196__340.jpg',
#  <http.client.HTTPMessage at 0x7fb2b1e75790>)

# %% [markdown]
# # Web Scraping do site ALURA MOTORS - Obtendo os dados de todos os anúncios de uma página

# %% [markdown]
# Identificando as informações no HTML

# %%
len(soup.find('div', {"id" : "container-cards"}).findAll('div', class_="card"))
# Out:
# 10

# %%
anuncios = soup.find('div', {"id" : "container-cards"}).findAll('div', class_="card")

# %%
for anuncio in anuncios:
  print(str(anuncio) + "\n\n")
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# ...

# %% [markdown]
# # Criando uma rotina de Scraping

# %%
# Valor
card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

# Informações
infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
for info in infos:
  card[info.get('class')[0].split('-')[-1]] = info.getText()

# Acessórios
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items.pop()
acessorios = []
for item in items:
  acessorios.append(item.getText().replace('► ', ''))
card['items'] = acessorios

# Imagens
image = anuncio.find('div', {'class': 'image-card'}).img
urlretrieve(image.get('src'), '/content/drive/MyDrive/WEB SCRAPPING/output/img' + image.get('src').split('/')[-1])
# Out:
# ('/content/drive/MyDrive/WEB SCRAPPING/output/imgtoyota-3245397__340.jpg',
#  <http.client.HTTPMessage at 0x7fb2b1e8f950>)

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

# Obtendo o HTML
url = 'https://alura-site-scraping.herokuapp.com/index.php' 

response = urlopen(url)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')

# Obtendo as TAGs de interesse
anuncios = soup.find('div', {"id" : "container-cards"}).findAll('div', class_="card")

# Coletando as informações dos CARDS
for anuncio in anuncios:
  card = {}

  # Valor
  card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

  # Informações
  infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
  for info in infos:
    card[info.get('class')[0].split('-')[-1]] = info.getText()

  # Acessórios
  items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
  items.pop()
  acessorios = []
  for item in items:
    acessorios.append(item.getText().replace('► ', ''))
  card['items'] = acessorios

  # Adicionando resultado a lista cards
  cards.append(card)
  # Imagens
  image = anuncio.find('div', {'class': 'image-card'}).img
  urlretrieve(image.get('src'), '/content/drive/MyDrive/WEB SCRAPPING/output/img' + image.get('src').split('/')[-1])

# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('/content/drive/MyDrive/WEB SCRAPPING/output/data/dataset.csv', sep = ';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#         value  ...   opportunity
# 0  R$ 338.000  ...           NaN
# 1  R$ 346.000  ...           NaN
# 2  R$ 480.000  ...           NaN
# 3  R$ 133.000  ...           NaN
# 4  R$ 175.000  ...           NaN
# 5  R$ 239.000  ...  OPORTUNIDADE
# 6  R$ 115.000  ...           NaN
# 7  R$ 114.000  ...           NaN
# 8   R$ 75.000  ...           NaN
# 9  R$ 117.000  ...  OPORTUNIDADE
#
# [10 rows x 8 columns]

# %% [markdown]
# # Web Scraping do site ALURA MOTORS - Obtendo os dados de todos os anúncios do site

# %%
int(soup.find('span', class_="info-pages").get_text().split()[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-2b3134f01c22> in <module>()
# ----> 1 int(soup.find('span', class_="info-pages").get_text().split()[-1])
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
soup.find('span class', class_="info-pages").get_text()

# %%
soup.find('span', class_="info-pages").get_text().split()

# %%
soup.find('span', class_="info-pages").get_text().split()[-1]

# %%
int(soup.find('span', class_="info-pages").get_text().split()[-1])
